# %%
import pandas as pd
import matplotlib.pylab as plt
from datetime import datetime
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
df = pd.read_csv('./seattle-library-checkout-records/most_checked_out_all.csv')
print(len(df))
# Out:
# 2947150

# %%
df.head()
# Out:
#    Unnamed: 0 author           description format_subgroup  num_checkouts  \
# 0           0    NaN         DVD: Adult/YA      Video Disc           2564
# 1           1    NaN         DVD: Adult/YA      Video Disc           2341
# 2           2    NaN         DVD: Adult/YA      Video Disc           2316
# 3           3    NaN         DVD: Adult/YA      Video Disc           2294
# 4           4    NaN  DVD: Juv Circulating      Video Disc           2224
#
#   publication_year                                          publisher  \
# 0           [2006]  Touchstone Home Entertainment : Distributed by...
# 1           [2006]                 Distributed by Universal Pictures,
# 2           c2005.                                 Warner Home Video,
# 3           [2006]  Focus Features : Distributed by Universal Stud...
# 4           c2005.                                 Warner Home Video,
#
#                                                title  year
# 0  Flightplan [videorecording] / Touchstone Pictu...  2006
# 1  Broken flowers [videorecording] / Bac Films ; ...  2006
# 2  March of the penguins [videorecording] / Bonne...  2006
# 3  The constant gardener [videorecording] / Potbo...  2006
# 4  Charlie and the chocolate factory [videorecord...  2006

# %%
def top_list(year, format_subgroup, k=5):
    top = df[df['year']==year][df['format_subgroup'].apply(lambda x: x in format_subgroup)].sort_values(by = 'num_checkouts', ascending = False)
    return top[['author','title','publication_year']].head(k)

# %%
for year in range(2006,2019):
    print('=======================================================================================')
    print(year)
    for format in [['Book'], ['Video Disc','Audio Disc', 'Music Score']]:
        print(format)
        print('=========')
        print(top_list(year, format, k=1))
    print('=======================================================================================')
# Out:
# =======================================================================================
# 2006
# ['Book']
# =========
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
#                 author                                              title  \
# 41  Maslen, Bobby Lynn  Bob books first! / text, Bobby Lynn Maslen ; p...
#
#    publication_year
# 41   [2000], c1976.
# ['Video Disc', 'Audio Disc', 'Music Score']
# =========
#   author                                              title publication_year
# 0    NaN  Flightplan [videorecording] / Touchstone Pictu...           [2006]
# =======================================================================================
# =======================================================================================
# 2007
# ['Book']
# =========
#                     author                                              title  \
# 121987  Maslen, Bobby Lynn  Bob books fun! / by Bobby Lynn Maslen ; pictur...
#
#        publication_year
# 121987            1999.
# ['Video Disc', 'Audio Disc', 'Music Score']
# =========
#        author                                              title  \
# 121957    NaN  Little Miss Sunshine [videorecording] / Big Be...
#
#        publication_year
# 121957           c2006.
# =======================================================================================
# =======================================================================================
# 2008
# ['Book']
# =========
#                  author                                              title  \
# 254709  Pollan, Michael  In defense of food : an eater's manifesto / Mi...
#
#        publication_year
# 254709            2008.
# ['Video Disc', 'Audio Disc', 'Music Score']
# =========
#        author                                              title  \
# 254595    NaN  Michael Clayton [videorecording] / Warner Bros...
#
#        publication_year
# 254595           [2008]
# =======================================================================================
# =======================================================================================
# 2009
# ['Book']
# =========
#        author                                              title  \
# 403302    NaN  Tropic thunder [videorecording] / DreamWorks ;...
#
#        publication_year
# 403302           c2008.
# ['Video Disc', 'Audio Disc', 'Music Score']
# =========
#        author                                              title  \
# 403277    NaN  Burn after reading [videorecording] / Focus Fe...
#
#        publication_year
# 403277           c2008.
# =======================================================================================
# =======================================================================================
# 2010
# ['Book']
# =========
#        author                                              title  \
# 571472    NaN  Tropic thunder [videorecording] / DreamWorks ;...
#
#        publication_year
# 571472           c2008.
# ['Video Disc', 'Audio Disc', 'Music Score']
# =========
#        author                                              title  \
# 571409    NaN  Doubt [videorecording] / Miramax Films ; produ...
#
#        publication_year
# 571409           [2009]
# =======================================================================================
# =======================================================================================
# 2011
# ['Book']
# =========
#                    author                         title publication_year
# 757424  Stockett, Kathryn  The help / Kathryn Stockett.           c2009.
# ['Video Disc', 'Audio Disc', 'Music Score']
# =========
#        author                                              title  \
# 757355    NaN  Up in the air [videorecording] / Paramount ; T...
#
#        publication_year
# 757355           [2010]
# =======================================================================================
# =======================================================================================
# 2012
# ['Book']
# =========
#                   author                                title publication_year
# 962393  Collins, Suzanne  The hunger games / Suzanne Collins.   [2009], c2008.
# ['Video Disc', 'Audio Disc', 'Music Score']
# =========
#        author                                              title  \
# 962346    NaN  Moneyball [videorecording] / Columbia Pictures...
#
#        publication_year
# 962346           [2012]
# =======================================================================================
# =======================================================================================
# 2013
# ['Book']
# =========
#                 author                                              title  \
# 1187505  Semple, Maria  Where'd you go, Bernadette : a novel / Maria S...
#
#         publication_year
# 1187505            2012.
# ['Video Disc', 'Audio Disc', 'Music Score']
# =========
#         author                                              title  \
# 1187504    NaN  Argo [videorecording] / Warner Bros. ; GK Film...
#
#         publication_year
# 1187504            2013.
# =======================================================================================
# =======================================================================================
# 2014
# ['Book']
# =========
#                author                         title publication_year
# 1442307  Tartt, Donna  The goldfinch / Donna Tartt.            2013.
# ['Video Disc', 'Audio Disc', 'Music Score']
# =========
#         author                                              title  \
# 1442292    NaN  American hustle [videorecording] / Columbia Pi...
#
#         publication_year
# 1442292           [2014]
# =======================================================================================
# =======================================================================================
# 2015
# ['Book']
# =========
#                  author                                   title  \
# 1718165  Hawkins, Paula  The girl on the train / Paula Hawkins.
#
#         publication_year
# 1718165            2015.
# ['Video Disc', 'Audio Disc', 'Music Score']
# =========
#         author                                              title  \
# 1718151    NaN  Gone girl [videorecording] / Twentieth Century...
#
#         publication_year
# 1718151           [2015]
# =======================================================================================
# =======================================================================================
# 2016
# ['Book']
# =========
#                  author                                   title  \
# 2014488  Hawkins, Paula  The girl on the train / Paula Hawkins.
#
#         publication_year
# 2014488            2015.
# ['Video Disc', 'Audio Disc', 'Music Score']
# =========
#         author                                              title  \
# 2014455    NaN  The Martian [videorecording] / Twentieth Centu...
#
#         publication_year
# 2014455           [2015]
# =======================================================================================
# =======================================================================================
# 2017
# ['Book']
# =========
#                            author  \
# 2623846  Whitehead, Colson, 1969-
#
#                                                      title publication_year
# 2623846  The Underground Railroad : a novel / Colson Wh...           [2016]
# ['Video Disc', 'Audio Disc', 'Music Score']
# =========
#         author                                              title  \
# 2623839    NaN  Arrival / Paramount Pictures ; Filmnation Ente...
#
#         publication_year
# 2623839           [2017]
# =======================================================================================
# =======================================================================================
# 2018
# ['Book']
# =========
#                 author                            title publication_year
# 2328445  Thomas, Angie  The hate u give / Angie Thomas.           [2017]
# ['Video Disc', 'Audio Disc', 'Music Score']
# =========
#         author                                              title  \
# 2328460    NaN  Get out / Universal Pictures ; Blumhouse Produ...
#
#         publication_year
# 2328460           [2017]
# =======================================================================================

# %%
top_list(2007, ['Video Disc','Audio Disc', 'Music Score'], 11)['title'][121957]
# Out:
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# 'Little Miss Sunshine [videorecording] / Big Beach Films ; Third Gear Productions LLC ; Deep River Productions ; Bona Fide Productions ; produced by Albert Berger, David T. Friendly, Peter Saraf, Marc Turtletaub, Ron Yerxa ; written by Michael Arndt ; directed by Jonathna Dayton, Valerie Faris.'

# %%
top_list(2008, ['Book'], 11)
# Out:
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
#                            author  \
# 254709            Pollan, Michael
# 254744             McMullan, Kate
# 254753    Martin, Bill, 1916-2004
# 254756            Mortenson, Greg
# 254757           Hosseini, Khaled
# 254759                McLeod, Bob
# 254762         Maslen, Bobby Lynn
# 254765             Cronin, Doreen
# 254772  Gilbert, Elizabeth, 1969-
# 254779        Kingsolver, Barbara
# 254782            Pollan, Michael
#
#                                                     title publication_year
# 254709  In defense of food : an eater's manifesto / Mi...            2008.
# 254744                    I stink! / Kate & Jim McMullan.           c2002.
# 254753  Chicka chicka boom boom / by Bill Martin, Jr. ...           c1989.
# 254756  Three cups of tea : one man's mission to fight...            2006.
# 254757        A thousand splendid suns / Khaled Hosseini.            2007.
# 254759                     SuperHero ABC / by Bob McLeod.            2006.
# 254762  Bob books fun! / by Bobby Lynn Maslen ; pictur...            1999.
# 254765  Giggle, giggle, quack / by Doreen Cronin ; pic...            2002.
# 254772  Eat, pray, love : one woman's search for every...            2006.
# 254779  Animal, vegetable, miracle : a year of food li...           c2007.
# 254782  The omnivore's dilemma : a natural history of ...            2006.
